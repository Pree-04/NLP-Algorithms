# %%
# imports
import string
import random
import nltk

from nltk.corpus import reuters
from nltk import FreqDist, ngrams
from nltk.corpus import stopwords
from collections import Counter, defaultdict

# %%
# input the reuters sentences
sents  =reuters.sents()

# %%
# write the removal characters such as : Stopwords and punctuation
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
string.punctuation = string.punctuation +'"'+'"'+'-'+'''+'''+'—'
string.punctuation
removal_list = list(stop_words) + list(string.punctuation)+ ['lt','rt']
removal_list
# Out:
# ['against',
#  'during',
#  'yourself',
#  'a',
#  'in',
#  'll',
#  'himself',
#  'the',
#  "hasn't",
#  'be',
#  "aren't",
#  "wasn't",
#  'her',
#  "couldn't",
#  'ourselves',
#  'she',
#  'for',
#  'above',
#  'him',
#  'about',
#  'under',
#  "doesn't",
#  'which',
#  'an',
#  'wasn',
#  'over',
#  'was',
#  'whom',
#  'when',
#  'being',
#  'no',
#  "hadn't",
#  'off',
#  "won't",
#  'can',
#  'these',
#  'or',
#  'to',
#  'does',
#  'from',
#  'been',
#  'm',
#  'mightn',
#  "it's",
#  'not',
#  'than',
#  'at',
#  'up',
#  'isn',
#  "mustn't",
#  'down',
#  'only',
#  'most',
#  'very',
#  'ours',
#  'there',
#  "you'll",
#  'and',
#  'on',
#  'you',
#  've',
#  'shouldn',
#  't',
#  'how',
#  'he',
#  "haven't",
#  'is',
#  "you'd",
#  'don',
#  'into',
#  'o',
#  'do',
#  'didn',
#  'their',
#  're',
#  'some',
#  'your',
#  'i',
#  'both',
#  'd',
#  'doesn',
#  "weren't",
#  'with',
#  "isn't",
#  'few',
#  'nor',
#  "she's",
#  'were',
#  'out',
#  'me',
#  'all',
#  'themselves',
#  'such',
#  'weren',
#  'below',
#  'yourselves',
#  "shan't",
#  'ma',
#  'now',
#  "shouldn't",
#  'those',
#  's',
#  'should',
#  'we',
#  'before',
#  'further',
#  'ain',
#  'mustn',
#  'but',
#  'his',
#  'are',
#  'will',
#  'while',
#  'hers',
#  'here',
#  'more',
#  'couldn',
#  "you've",
#  "wouldn't",
#  "that'll",
#  'of',
#  'any',
#  'by',
#  'once',
#  'itself',
#  'having',
#  'it',
#  'has',
#  'each',
#  'hadn',
#  'who',
#  'y',
#  'through',
#  'just',
#  'then',
#  'them',
#  'had',
#  'herself',
#  'its',
#  'as',
#  'if',
#  'other',
#  'our',
#  'am',
#  'between',
#  'myself',
#  'again',
#  'this',
#  'too',
#  "you're",
#  'they',
#  'doing',
#  'so',
#  'until',
#  'where',
#  'that',
#  "didn't",
#  "don't",
#  'needn',
#  'own',
#  'theirs',
#  'wouldn',
#  'what',
#  'because',
#  'shan',
#  'have',
#  "should've",
#  'won',
#  "mightn't",
#  'aren',
#  'haven',
#  "needn't",
#  'why',
#  'did',
#  'same',
#  'yours',
#  'my',
#  'hasn',
#  'after',
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  '"',
#  '"',
#  '-',
#  '+',
#  '—',
#  'lt',
#  'rt']

# %%
# generate unigrams bigrams trigrams
unigram=[]
bigram=[]
trigram=[]
tokenized_text=[]
for sentence in sents:
  sentence = list(map(lambda x:x.lower(),sentence))
  for word in sentence:
        if word== '.':
            sentence.remove(word) 
        else:
            unigram.append(word)
    
  tokenized_text.append(sentence)
  bigram.extend(list(ngrams(sentence, 2,pad_left=True, pad_right=True)))
  trigram.extend(list(ngrams(sentence, 3, pad_left=True, pad_right=True)))

# %%
# remove the n-grams with removable words
def remove_stopwords(x):     
    y = []
    for pair in x:
        count = 0
        for word in pair:
            if word in removal_list:
                count = count or 0
            else:
                count = count or 1
        if (count==1):
            y.append(pair)
    return (y)
unigram = remove_stopwords(unigram)
bigram = remove_stopwords(bigram)
trigram = remove_stopwords(trigram)

# %%
# generate frequency of n-grams 
freq_bi = FreqDist(bigram)
freq_tri = FreqDist(trigram)
  
d = defaultdict(Counter)
for ngram, count in freq_tri.items():
    a, b, c = ngram
    if (a is not None) and (b is not None) and (c is not None):
        d[a, b][c] += count

# %%
# Next word prediction      
s=''
def pick_word(counter):
    "Chooses a random element."
    return random.choice(list(counter.elements()))
prefix = "he", "said"
print(" ".join(prefix))
s = " ".join(prefix)
for i in range(19):
    suffix = pick_word(d[prefix])
    s=s+' '+suffix
    print(s)
    prefix = prefix[1], suffix
# Out:
# he said
# he said the
# he said the debate
# he said the debate on
# he said the debate on a
# he said the debate on a schedule
# he said the debate on a schedule of
# he said the debate on a schedule of lending
# he said the debate on a schedule of lending ratings
# he said the debate on a schedule of lending ratings assigned
# he said the debate on a schedule of lending ratings assigned according
# he said the debate on a schedule of lending ratings assigned according to
# he said the debate on a schedule of lending ratings assigned according to a
# he said the debate on a schedule of lending ratings assigned according to a drop
# he said the debate on a schedule of lending ratings assigned according to a drop of
# he said the debate on a schedule of lending ratings assigned according to a drop of 14
# he said the debate on a schedule of lending ratings assigned according to a drop of 14 06
# he said the debate on a schedule of lending ratings assigned according to a drop of 14 06 marks
# he said the debate on a schedule of lending ratings assigned according to a drop of 14 06 marks per
# he said the debate on a schedule of lending ratings assigned according to a drop of 14 06 marks per ordinary
